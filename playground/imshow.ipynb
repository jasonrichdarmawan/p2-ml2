# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig, axes = plt.subplots(nrows=1, ncols=3)

for ax in axes.ravel():
    img = mpimg.imread('../data/Apple/Apple A/Apple 1.png')
    ax.imshow(img)
    ax.set_title('Apple A')
